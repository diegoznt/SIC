# %% [markdown]
# <a href="https://colab.research.google.com/github/diegoznt/SIC/blob/main/ejemplo1_SIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,10,100)
y=np.sin(x)

plt.plot(x,y)
plt.title("Ejemplo")
plt.show()

# %% [markdown]
# Ejemplo practico
